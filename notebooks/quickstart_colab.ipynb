# %% [markdown]
# # 🏛️ Autonomous Equity Research & DCF Modeling Agent
# Welcome to the interactive notebook for the **Autonomous Equity Research & Valuation Agent**.
#
# This tool ingests live exchange market data, computes fully articulated 10-tab Excel models (`.xlsx`), renders publication-grade 16-page PDF research reports, and performs multi-method DCF & relative valuation.

# %%
# 1. Clone the repository and install requirements
# !git clone https://github.com/siddheshumrigar-tech/equity-research-agent.git
# %cd equity-research-agent
# !pip install -r requirements.txt

# %%
# 2. Run the agent for ANY stock (e.g. TCS on NSE or AAPL on NASDAQ)
# !python generate_equity_report.py --ticker TCS.NS --output_dir ./output

# %%
# 3. Download the generated Excel Model and PDF Report
from google.colab import files
import glob

for f in glob.glob('./output/*.*'):
    print(f'Downloading {f}...')
    files.download(f)
